# %% [markdown]
# # **Creation of the ZAGIMORE DB**
#
# For material, please look into
# [Supplementary HERE](https://dbtextbook.com/supplementary.html )

# %% [markdown]
# This code allows to viz DB without errors

# %%
# Local setup: install packages once from the terminal with `python -m pip install -r requirements.txt`.

# %% [markdown]
# This cell let Colab access the content in our GoogleDrive

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd()
while PROJECT_ROOT != PROJECT_ROOT.parent and not (
    (PROJECT_ROOT / "README.md").exists()
    and (PROJECT_ROOT / "requirements.txt").exists()
):
    PROJECT_ROOT = PROJECT_ROOT.parent

if not (PROJECT_ROOT / "requirements.txt").exists():
    raise FileNotFoundError(
        "Could not find the project root. Start Jupyter from the DataManagement-BusinessIntelligence folder."
    )

db_file = PROJECT_ROOT / "zagimore.db"

# %% [markdown]
# This code removes any existing database with the same name of the one we are about to create

# %%
if db_file.exists():
    db_file.unlink()

# %%
# Set-up
db_path = db_file.resolve().as_posix()
connection_string = f"sqlite:///{db_path}"

# %load_ext sql
# %config SqlMagic.style = 'DEFAULT'
# %sql $connection_string

# %% [markdown]
# In the following, we are using SQL syntax with instructions on how to create the tables within our database.
#
# https://dbtextbook.com/downloads/Chapter5SQLStatementsIBMDB2.pdf

# %%
# %%sql
#
# DROP TABLE IF EXISTS vendor;
# CREATE TABLE vendor (
#   vendorid     CHAR(2)  NOT NULL,
#   vendorname  VARCHAR(25)   NOT NULL,
#   PRIMARY KEY (vendorid) );
#
# DROP TABLE IF EXISTS category;
# CREATE TABLE category (
#   categoryid     CHAR(2)   NOT NULL,
#   categoryname   VARCHAR(25)   NOT NULL,
#   PRIMARY KEY (categoryid) );
#
# DROP TABLE IF EXISTS product;
# CREATE TABLE product (
#   productid    CHAR(3)   NOT NULL,
#   productname  VARCHAR(25)   NOT NULL,
#   productprice  NUMERIC(7,2)  NOT NULL,
#   vendorid     CHAR(2)   NOT NULL,
#   categoryid    CHAR(2)   NOT NULL,
#   PRIMARY KEY (productid),
#   FOREIGN KEY (vendorid)
#   REFERENCES vendor(vendorid),
#   FOREIGN KEY (categoryid) REFERENCES  category(categoryid) );
#
# DROP TABLE IF EXISTS region;
# CREATE TABLE region (
#   regionid     CHAR   NOT NULL,
#   regionname  VARCHAR(25)   NOT NULL,
#   PRIMARY KEY (regionid) );
#
# DROP TABLE IF EXISTS store;
# CREATE TABLE store (
#   storeid     VARCHAR(3)   NOT NULL,
#   storezip  CHAR(5)   NOT NULL,
#   regionid     CHAR   NOT NULL,
#   PRIMARY KEY (storeid),
#   FOREIGN KEY (regionid) REFERENCES region(regionid) );
#
# DROP TABLE IF EXISTS customer;
# CREATE TABLE customer (
#   customerid   CHAR(7)   NOT NULL,
#   customername   VARCHAR(15)   NOT NULL,
#   customerzip   CHAR(5)   NOT NULL,
#   PRIMARY KEY (customerid)
#   );
#
# DROP TABLE IF EXISTS salestransaction;
# CREATE TABLE salestransaction (
#   tid      VARCHAR(8)   NOT NULL,
#   customerid  CHAR(7)   NOT NULL,
#   storeid  VARCHAR(3)   NOT NULL,
#   tdate   DATE   NOT NULL,
#   PRIMARY KEY (tid),
#   FOREIGN KEY (customerid) REFERENCES  customer(customerid),
#   FOREIGN KEY (storeid) REFERENCES store(storeid));
#
# DROP TABLE IF EXISTS soldvia;
# CREATE TABLE soldvia (
#   productid    CHAR(3)   NOT NULL,
#   tid      VARCHAR(8)   NOT NULL,
#   noofitems  INT   NOT NULL,
#   PRIMARY KEY (productid, tid),
#   FOREIGN KEY (productid) REFERENCES product(productid),
#   FOREIGN KEY (tid) REFERENCES salestransaction(tid)
# );
# Out:
#  * sqlite:////Users/vanessadamario/src/DataManagement-BusinessIntelligence/zagimore.db
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %% [markdown]
# In the following lines, we get the instructions to create the file zagimore_inserts.sql with all lines for data INSERT in the tables.
#
# https://dbtextbook.com/downloads/ZAGIMOREINSERTINTOstatementsMySQL.txt

# %%
from urllib.request import urlretrieve

urlretrieve(
    "https://dbtextbook.com/downloads/ZAGIMOREINSERTINTOstatementsMySQL.txt",
    "zagimore_inserts.sql",
)
# Out:
# ('zagimore_inserts.sql', <http.client.HTTPMessage at 0x114bce350>)

# %%
with open('zagimore_inserts.sql') as f:
    sql = f.read()
# %sql $sql
# Out:
#  * sqlite:////Users/vanessadamario/src/DataManagement-BusinessIntelligence/zagimore.db
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# ...

# %%
# !grep "INSERT INTO product" zagimore_inserts.sql | head

# %%
# %%sql
# SELECT COUNT(*) FROM product;
# Out:
#  * sqlite:////Users/vanessadamario/src/DataManagement-BusinessIntelligence/zagimore.db
# Done.
# [(24,)]

# %%
# %sql $connection_string

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type='table';
# Out:
#  * sqlite:////Users/vanessadamario/src/DataManagement-BusinessIntelligence/zagimore.db
# Done.
# [('vendor',),
#  ('category',),
#  ('product',),
#  ('region',),
#  ('store',),
#  ('customer',),
#  ('salestransaction',),
#  ('soldvia',)]

# %%
# %%sql
# SELECT * FROM product;
# Out:
#  * sqlite:////Users/vanessadamario/src/DataManagement-BusinessIntelligence/zagimore.db
# Done.
# [('1X1', 'Zzz Bag', 100, 'PG', 'CP'),
#  ('2X2', 'Easy Boot', 70, 'MK', 'FW'),
#  ('3X3', 'Cosy Sock', 15, 'MK', 'FW'),
#  ('4X4', 'Dura Boot', 90, 'PG', 'FW'),
#  ('5X5', 'Tiny Tent', 150, 'MK', 'CP'),
#  ('6X6', 'Biggy Tent', 250, 'MK', 'CP'),
#  ('7X7', 'Hi-Tec GPS', 300, 'OA', 'EL'),
#  ('8X8', 'Power Pedals', 20, 'MK', 'CY'),
#  ('9X9', 'Trusty Rope', 30, 'WL', 'CL'),
#  ('1X2', 'Comfy Harness', 150, 'MK', 'CL'),
#  ('1X3', 'Sunny Charger', 125, 'OA', 'EL'),
#  ('1X4', 'Safe-T Helmet', 40, 'PG', 'CY'),
#  ('2X1', 'Mmm Stove', 80, 'WL', 'CP'),
#  ('2X3', 'Reflect-o Jacket', 35, 'PG', 'CY'),
#  ('2X4', 'Strongster Carribeaner', 20, 'MK', 'CL'),
#  ('3X1', 'Sleepy Pad', 25, 'WL', 'CP'),
#  ('3X2', 'Bucky Knife', 60, 'WL', 'CP'),
#  ('3X4', 'Treado Tire', 30, 'OA', 'CY'),
#  ('4X1', 'Slicky Tire', 25, 'OA', 'CY'),
#  ('4X2', 'Electra Compass', 45, 'MK', 'EL'),
# ...
