# %% [markdown]
# # Week 3 - Loading the HAFH Database Locally
#
# This notebook uses the local project folder and the local SQLite file `HAFH.db`.

# %% [markdown]
# ## Running This Notebook in Jupyter
#
# Start Jupyter from the project root in Terminal:
#
# ```bash
# cd /Users/vanessadamario/src/DataManagement-BusinessIntelligence
# conda activate bia5476-local
# jupyter lab
# ```
#
# Then open this notebook, select the kernel `Python (BIA5476 local)`, and run the cells from top to bottom with `Shift` + `Enter`. The setup cell below connects the notebook to `HAFH.db`, so the SQL cells can run locally.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd()
while PROJECT_ROOT != PROJECT_ROOT.parent and not (
    (PROJECT_ROOT / "README.md").exists()
    and (PROJECT_ROOT / "requirements.txt").exists()
):
    PROJECT_ROOT = PROJECT_ROOT.parent

if not (PROJECT_ROOT / "requirements.txt").exists():
    raise FileNotFoundError(
        "Could not find the project root. Start Jupyter from the DataManagement-BusinessIntelligence folder."
    )

db_path = (PROJECT_ROOT / "HAFH.db").resolve().as_posix()
connection_string = f"sqlite:///{db_path}"

# %reload_ext sql
# %sql $connection_string

# %%
# %%sql
#
# SELECT name FROM sqlite_master WHERE type='table';
# Out:
#  * sqlite:////Users/vanessadamario/src/DataManagement-BusinessIntelligence/HAFH.db
# Done.
# [('manager',),
#  ('managerphone',),
#  ('building',),
#  ('inspector',),
#  ('inspecting',),
#  ('corpclient',),
#  ('apartment',),
#  ('staffmember',),
#  ('cleaning',)]

# %%
# %%sql
#
# select * from staffmember;
# Out:
#  * sqlite:////Users/vanessadamario/src/DataManagement-BusinessIntelligence/HAFH.db
# Done.
# [('5432', 'Brian'),
#  ('9876', 'Boris'),
#  ('7652', 'Caroline'),
#  ('2537', 'Howard'),
#  ('3984', 'Luis'),
#  ('4196', 'Arthur'),
#  ('8467', 'Mariana'),
#  ('1028', 'Franz')]
